# %% [markdown]
# # **what is mean by Machine learning?**

# %% [markdown]
# **ML stands for Machine Learning, which is a branch of artificial intelligence (AI) that enables computers to learn from data and make decisions or predictions without being explicitly programmed.**
#
# **It involves training models using algorithms that find patterns in data and improve their performance over time. Machine learning is widely used in various applications such as:**
#
# Spam detection (e.g., filtering spam emails)
#
# Image recognition (e.g., facial recognition in photos)
#
# Recommendation systems (e.g., Netflix or YouTube recommendations)
#
# Predictive analytics (e.g., stock market prediction)

# %% [markdown]
# ![Mac.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 091530.png](data:image/png;base64,...)

# %% [markdown]
# # **Supervised Learning**
#
# Supervised learning is a type of machine learning where the model is trained on labeled data (i.e., input-output pairs). The goal is to learn a function that maps inputs to desired outputs.
#
# 🔹 **Types of Supervised Learning:**
#
# Regression (Predicting continuous values)
#
# Classification (Predicting discrete categories or class type of data)

# %% [markdown]
# # **What is Linear Regression?**
#
# Linear Regression is a supervised learning algorithm used for predicting continuous values. It finds a relationship between an independent variable (X) and a dependent variable (Y) by fitting a straight line.

# %% [markdown]
# ![ln.png](data:image/png;base64,...)

# %% [markdown]
# ![slope.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Formula of Linear Regression
# 𝑌 = 𝑚𝑋+𝑏
# ```

# %% [markdown]
# ![Screenshot 2025-03-18 083717.png](data:image/png;base64,...)

# %% [markdown]
# where:
#
# Y = Predicted output (House Price)
#
# X = Input feature (Square footage, number of bedrooms, etc.)
#
# m = Slope (Rate of change)
#
# b = Intercept (Value of Y when X=0)
#
# The goal is to find the best values for

# %% [markdown]
# ![Screenshot 2025-03-18 084757.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 084939.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 090128.png](data:image/png;base64,...)

# %% [markdown]
# # **What is Polynomial Regression?**
#
# Polynomial Regression is an extension of Linear Regression, used when the relationship between independent (X) and dependent (Y) variables is non-linear. Instead of fitting a straight line, it fits a curved (polynomial) line to the data.

# %% [markdown]
# ![Screenshot 2025-03-18 091845.png](data:image/png;base64,...)

# %% [markdown]
# # **what is mean by Support Vector Regression (SVR)?**
#
# Support Vector Regression (SVR) is an extension of Support Vector Machines (SVM) used for regression tasks. Instead of classifying data points into categories, SVR predicts continuous values while maintaining the principles of maximizing the margin.

# %% [markdown]
# ![Screenshot 2025-03-18 095010.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 095121.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 095201.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 095246.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 100044.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 095437.png](data:image/png;base64,...)

# %% [markdown]
# # **What is Happening to Our Data with the RBF Kernel in SVR?**
#
# When we choose the Radial Basis Function (RBF) kernel, we are transforming our data into a higher-dimensional space where it can be better separated or modeled in a linear way. Let’s break this down step by step in a simple way.

# %% [markdown]
# ![Screenshot 2025-03-18 101147.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 112601.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 112650.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 113844.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 114030.png](data:image/png;base64,...)

# %% [markdown]
# # **Decision Tree Regression**
#
# Decision Tree Regression is a non-linear model that splits the data into smaller regions based on conditions and makes predictions using the mean value of the data points in each region.

# %% [markdown]
# ![Screenshot 2025-03-18 120220.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 121142.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 120727.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 120757.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 120905.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#                ┌───────────────────┐
#                | Crude Oil ≤ 85 ?   |
#                └───────────────────┘
#                       │
#         ┌─────────────┴──────────────┐
#         ▼                            ▼
#    ┌──────────────┐           ┌───────────────────┐
#    | Fuel Price = |           | Crude Oil ≤ 90 ?  |
#    |    3.3       |           └───────────────────┘
#    └──────────────┘                   │
#                       ┌───────────────┴───────────────┐
#                       ▼                               ▼
#                ┌──────────────┐                 ┌───────────────────┐
#                | Fuel Price = |                 | Crude Oil ≤ 95 ?  |
#                |    3.6       |                 └───────────────────┘
#                └──────────────┘                        │
#                                                        ▼
#                                                ┌──────────────┐
#                                                | Fuel Price = |
#                                                |    3.7       |
#                                                └──────────────┘
#
# ```

# %% [markdown]
# # **Neural Network Regression ?**
#
# Neural Network Regression is a type of neural network used to predict continuous values (numbers). It helps in forecasting things like Bitcoin prices, house prices, or stock values instead of classifying things into categories.

# %% [markdown]
# ![Screenshot 2025-03-18 144536.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 145706.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 145738.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 145806.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-18 145839.png](data:image/png;base64,...)
