# %% [markdown]
# # **what is mean by Association Rule Learning?**

# %% [markdown]
# **Association Rule Learning (ARL) is an unsupervised learning technique used to identify interesting relationships or patterns between items in large datasets.**
#
# It helps find rules like:
#
# 💡 "If a customer buys item A, they are likely to buy item B."

# %% [markdown]
# ![Screenshot 2025-03-19 145922.png](data:image/png;base64,...)

# %% [markdown]
# # **Popular Algorithms**
#
# Apriori Algorithm – Finds frequent itemsets using support and generates association rules.
#
# Eclat Algorithm – Similar to Apriori but uses depth-first search for efficiency.
#
# FP-Growth – Faster than Apriori, works well with large datasets.

# %% [markdown]
# # **Apriori Algorithm for Netflix Movie Recommendations**
#
# We can use the Apriori algorithm to find relationships between movies that users frequently watch together. This helps recommend similar movies based on user viewing patterns.

# %% [markdown]
# ![Screenshot 2025-03-19 152632.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 152906.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 153003.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 153052.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 153125.png](data:image/png;base64,...)

# %% [markdown]
# # **Conclusion**
#
# By applying the Apriori algorithm to Netflix's movie watch history, we identified strong associations between movies based on user viewing patterns. The analysis revealed that users who watched "The Matrix" were most likely to watch "Interstellar", making it the strongest recommendation. Other associations, such as between "Inception" and "The Matrix," had moderate confidence but lower lift, indicating weaker connections.
#
# Using Support, Confidence, and Lift, Netflix can personalize recommendations, improving user engagement and satisfaction. This approach helps in predicting user preferences and suggesting relevant movies, enhancing the overall viewing experience.

# %% [markdown]
# # **Eclat Algorithm in Shopping Product Recommendation**
#
# The Eclat (Equivalence Class Clustering and Bottom-Up Lattice Traversal) Algorithm is an efficient frequent itemset mining algorithm used for product recommendations. Unlike Apriori, which uses a breadth-first approach, Eclat uses a depth-first search (DFS) to find frequent itemsets.

# %% [markdown]
# ![Screenshot 2025-03-19 154400.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 154435.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 154556.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 154800.png](data:image/png;base64,...)

# %% [markdown]
# # **📌 Conclusion**
#
# The Eclat algorithm efficiently finds frequent product combinations using depth-first search (DFS) and TID-sets, making it faster than Apriori for large datasets. In this case, we discovered that Milk and Bread are often bought together (60% support), making them strong recommendations. This approach helps e-commerce platforms and supermarkets suggest products to customers, increasing sales and improving the shopping experience.

# %% [markdown]
# # **FP-Growth Algorithm for Books in the World:**
#
# FP-Growth (Frequent Pattern Growth) is a popular algorithm for mining frequent itemsets in a transaction dataset without generating candidate sets like the Apriori algorithm. It is especially useful when dealing with large datasets, such as book purchasing patterns worldwide.

# %% [markdown]
# ![Screenshot 2025-03-19 163152.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 163220.png](data:image/png;base64,...)

# %% [markdown]
# # **Step 4: Build the FP-Tree**

# %% [markdown]
# ![Screenshot 2025-03-19 164315.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 164349.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 164419.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 164616.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 164717.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-03-19 164757.png](data:image/png;base64,...)

# %% [markdown]
# # **Conclusion**
#
# The FP-Growth algorithm builds a tree structure to find frequently bought books together. It increases counts for existing items and creates new branches when needed. This helps in quickly identifying book associations and making recommendations. Businesses can use this to suggest books customers are likely to buy, improving sales and user experience efficiently.
